# %%
import pandas as pd 

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import os
from pathlib import Path
import sys


module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    

# My own credenctials
from utils.config import SpotifyCredectials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qf/q5wbqd8x5vl664hcs_10cghw0000gn/T/ipykernel_2617/3497909716.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 import spotipy
#       4 from spotipy.oauth2 import SpotifyClientCredentials
#       5
#
# ModuleNotFoundError: No module named 'spotipy'

# %% [markdown]
# ## API Intialization

# %% [markdown]
# #### Set your spotify credentials

# %%
# Get my credentials. 
# Please define your own Spotify Developper credentilals

cred = SpotifyCredectials()

my_id = cred.my_id
my_secret = cred.my_secret

# %% [markdown]
# #### Intialize Spotify API

# %%
ccm = SpotifyClientCredentials(client_id = my_id, client_secret = my_secret)
spotify = spotipy.Spotify(client_credentials_manager = ccm)

# %% [markdown]
# ## Search Artist

# %%
artist_search_keyword = 'Oasis'

# %% [markdown]
# #### Find artist in Spotify

# %%
results = spotify.search(artist_search_keyword, limit=5, offset=0, type='artist', market=None)

result_list = []
for idx, artist in enumerate(results['artists']['items']):
    result_list.append({'artist': artist['name'], 
                                    'followers': artist['followers']['total'], 
                                     'popularity': artist['popularity'], 
                                    'genres': artist['genres'], 
                                     'external_urls': artist['external_urls']['spotify'], 
                                    'artist': artist['name'],       
                                    'href': artist['href'], 
                                    'id': artist['id'], 
                                     'uri': artist['uri']
    })
    
result_artists_df = pd.DataFrame(result_list).sort_values(by = ['followers'], ascending = False)

# Get search result 
result_artists_df = result_artists_df[result_artists_df['artist']==artist_search_keyword]
result_artists_df
# Out:
#   artist  followers  popularity  \
# 0  Oasis    8147488          77
#
#                                               genres  \
# 0  [beatlesque, britpop, madchester, permanent wa...
#
#                                        external_urls  \
# 0  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/2DaxqgrOhke...  2DaxqgrOhkeH0fpeiQq2f4
#
#                                      uri
# 0  spotify:artist:2DaxqgrOhkeH0fpeiQq2f4

# %% [markdown]
# ## Get top songs

# %%
artist_url =result_artists_df['uri'][0]
results = spotify.artist_top_tracks(artist_url)


top_song_list = []
for track in results['tracks'][:10]:
    top_song_list.append({'track': track['name'], 
                                  'popularity': track['popularity'],
                                    'audio': track['preview_url'],     
                                     'cover art': track['album']['images'][0]['url']
                                    })
    
top_song_df = pd.DataFrame(top_song_list)
top_song_df.head()
# Out:
#                                    track  popularity  \
# 0                Wonderwall - Remastered          78
# 1  Don't Look Back In Anger - Remastered          73
# 2             Stop Crying Your Heart Out          66
# 3       Champagne Supernova - Remastered          68
# 4              Live Forever - Remastered          66
#
#                                                audio  \
# 0  https://p.scdn.co/mp3-preview/6b7c37bb7af0b116...
# 1  https://p.scdn.co/mp3-preview/f2e28606ab3c2459...
# 2  https://p.scdn.co/mp3-preview/27198f8fdf352238...
# 3  https://p.scdn.co/mp3-preview/09eb6b89a0a2f2a5...
# 4  https://p.scdn.co/mp3-preview/08a870fa4ed4cf32...
#
#                                            cover art
# 0  https://i.scdn.co/image/ab67616d0000b2737a4c8c...
# 1  https://i.scdn.co/image/ab67616d0000b2737a4c8c...
# 2  https://i.scdn.co/image/ab67616d0000b273bd1486...
# 3  https://i.scdn.co/image/ab67616d0000b2737a4c8c...
# 4  https://i.scdn.co/image/ab67616d0000b273d86a1e...

# %% [markdown]
# ## Get all albums of the searched artist

# %%
album_result = spotify.artist_albums(artist_url)

album_dic_list = []
for album in album_result['items']:
    album_dic_list.append({"name":album["name"],
                                       "release_date":album["release_date"],
                                       "total_tracks":album["total_tracks"],
                                        "album_group":album["album_group"],
                                        "album_type":album["album_type"],
                                        "artists":album["artists"][0]['external_urls']['spotify'],
                                        "available_markets":album["available_markets"],
                                        "external_urls":album["external_urls"]['spotify'],
                                        "href":album["href"],
                                        "id":album["id"],
                                        "images":album["images"],
                                        "release_date_precision":album["release_date_precision"],
                                        "type":album["type"],
                                        "uri":album["uri"]
    })
    
all_albums_df = pd.DataFrame(album_dic_list)
all_albums_df.head()
# Out:
#                                       name release_date  total_tracks  \
# 0                    Knebworth 1996 (Live)   2021-11-19            20
# 1                     Oasis Knebworth 1996   2021-11-19            20
# 2                    Knebworth 1996 (Live)   2021-11-19            20
# 3                  Be Here Now(Remastered)   2016-10-14            12
# 4  Be Here Now(Remastered)(Deluxe Edition)   2016-10-05            40
#
#   album_group album_type                                            artists  \
# 0       album      album  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
# 1       album      album  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
# 2       album      album  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
# 3       album      album  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
# 4       album      album  https://open.spotify.com/artist/2DaxqgrOhkeH0f...
#
#                                    available_markets  \
# 0                                               [JP]
# 1  [AE, AG, AL, AM, AO, AR, AZ, BA, BB, BD, BF, B...
# 2  [AT, AU, BE, CA, CH, CW, DE, DK, EE, ES, FI, F...
# 3                                               [JP]
# 4                                               [JP]
#
#                                        external_urls  \
# 0  https://open.spotify.com/album/2jAVKPE49R8HwPP...
# 1  https://open.spotify.com/album/2VWgKzOzehWHP3j...
# 2  https://open.spotify.com/album/5TC9oSol9ZQwXQk...
# 3  https://open.spotify.com/album/4BCOxFkJvT2WCSg...
# 4  https://open.spotify.com/album/0q0IOjjhk66mFdA...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/2jAVKPE49R8H...  2jAVKPE49R8HwPPbY1vdSs
# 1  https://api.spotify.com/v1/albums/2VWgKzOzehWH...  2VWgKzOzehWHP3jIwcwtYq
# 2  https://api.spotify.com/v1/albums/5TC9oSol9ZQw...  5TC9oSol9ZQwXQk8XcsD7i
# 3  https://api.spotify.com/v1/albums/4BCOxFkJvT2W...  4BCOxFkJvT2WCSgh3ng74W
# 4  https://api.spotify.com/v1/albums/0q0IOjjhk66m...  0q0IOjjhk66mFdABKpTPkp
#
#                                               images release_date_precision  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    day
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    day
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    day
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    day
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...                    day
#
#     type                                   uri
# 0  album  spotify:album:2jAVKPE49R8HwPPbY1vdSs
# 1  album  spotify:album:2VWgKzOzehWHP3jIwcwtYq
# 2  album  spotify:album:5TC9oSol9ZQwXQk8XcsD7i
# 3  album  spotify:album:4BCOxFkJvT2WCSgh3ng74W
# 4  album  spotify:album:0q0IOjjhk66mFdABKpTPkp

# %% [markdown]
# ## Get all songs of the searched artist

# %%
all_album_ids = list(all_albums_df['id'])

album_tracks_df_list = []
for album_id in all_album_ids:
    album_track_result = spotify.album_tracks(album_id, limit=50, offset=0, market=None)
    track_list = []
    for track in album_track_result['items']:        
        track_list.append({"name":track["name"],
                                   "track_number":track["track_number"],
                                   "id":track["id"],
                                    "artists":track["artists"],
                                    "available_markets":track["available_markets"],
                                    "disc_number":track["disc_number"],
                                    "duration_ms":track["duration_ms"],
                                    "explicit":track["explicit"],
                                    "external_urls":track["external_urls"],
                                    "href":track["href"],
                                    "is_local":track["is_local"],
                                    "preview_url":track["preview_url"],
                                    "type":track["type"],
                                    "uri":track["uri"] })

    single_album_tracks_df = pd.DataFrame(track_list)
    album_tracks_df_list.append(single_album_tracks_df)

all_songs_df = pd.concat(album_tracks_df_list)
all_songs_df.head()
# Out:
#                                                 name  track_number  \
# 0        Columbia - Live at Knebworth, 10 August '96             1
# 1       Acquiesce - Live at Knebworth, 10 August '96             2
# 2      Supersonic - Live at Knebworth, 10 August '96             3
# 3           Hello - Live at Knebworth, 11 August '96             4
# 4  Some Might Say - Live at Knebworth, 11 August '96             5
#
#                        id                                            artists  \
# 0  4GCJnyQmXZG9nBxxTuQ9E4  [{'external_urls': {'spotify': 'https://open.s...
# 1  0VAZaVLciiPPfS0onyzRwD  [{'external_urls': {'spotify': 'https://open.s...
# 2  1gzwbFfjM0VR6q9g230SBW  [{'external_urls': {'spotify': 'https://open.s...
# 3  0mpH8yWOUFc6HaucHdBffI  [{'external_urls': {'spotify': 'https://open.s...
# 4  2jdUm82MOuoA0VajeYDDGz  [{'external_urls': {'spotify': 'https://open.s...
#
#   available_markets  disc_number  duration_ms  explicit  \
# 0              [JP]            1       287722     False
# 1              [JP]            1       236778     False
# 2              [JP]            1       309880     False
# 3              [JP]            1       175536     False
# 4              [JP]            1       304629     False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4G...
# 1  {'spotify': 'https://open.spotify.com/track/0V...
# 2  {'spotify': 'https://open.spotify.com/track/1g...
# 3  {'spotify': 'https://open.spotify.com/track/0m...
# 4  {'spotify': 'https://open.spotify.com/track/2j...
#
#                                                 href  is_local  \
# 0  https://api.spotify.com/v1/tracks/4GCJnyQmXZG9...     False
# 1  https://api.spotify.com/v1/tracks/0VAZaVLciiPP...     False
# 2  https://api.spotify.com/v1/tracks/1gzwbFfjM0VR...     False
# 3  https://api.spotify.com/v1/tracks/0mpH8yWOUFc6...     False
# 4  https://api.spotify.com/v1/tracks/2jdUm82MOuoA...     False
#
#                                          preview_url   type  \
# 0  https://p.scdn.co/mp3-preview/572befc845e99984...  track
# 1  https://p.scdn.co/mp3-preview/735c669d7b7ee08a...  track
# 2  https://p.scdn.co/mp3-preview/4299fda6c74ed061...  track
# 3  https://p.scdn.co/mp3-preview/7a18be1b97d9b04b...  track
# 4  https://p.scdn.co/mp3-preview/898b9bad7ecc0e84...  track
#
#                                     uri
# 0  spotify:track:4GCJnyQmXZG9nBxxTuQ9E4
# 1  spotify:track:0VAZaVLciiPPfS0onyzRwD
# 2  spotify:track:1gzwbFfjM0VR6q9g230SBW
# 3  spotify:track:0mpH8yWOUFc6HaucHdBffI
# 4  spotify:track:2jdUm82MOuoA0VajeYDDGz

# %% [markdown]
# ## Get all songs with audio features

# %%
all_song_feature_df_list = []

for n in range(1, int(len(all_songs_df)/100)+2):
    if n!=1:
        start_index = 100*(n-1)
        end_index = 100*n
    else:
        start_index = 0
        end_index = 100
    
    song_feat_result = spotify.audio_features(list(all_songs_df['id'][start_index:end_index]))
    song_feat_result_df = pd.DataFrame(song_feat_result)
    song_feat_result_df.insert(0, 'name', list(all_songs_df['name'][start_index:end_index]))
        
    all_song_feature_df_list.append(song_feat_result_df)
    
all_song_feature_df = pd.concat(all_song_feature_df_list)
all_song_feature_df.head()
# Out:
#                                                 name  danceability  energy  \
# 0        Columbia - Live at Knebworth, 10 August '96         0.281   0.800
# 1       Acquiesce - Live at Knebworth, 10 August '96         0.258   0.921
# 2      Supersonic - Live at Knebworth, 10 August '96         0.268   0.932
# 3           Hello - Live at Knebworth, 11 August '96         0.120   0.956
# 4  Some Might Say - Live at Knebworth, 11 August '96         0.168   0.871
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    2    -4.930     1       0.0449      0.000020             0.869     0.984
# 1    0    -4.646     1       0.0647      0.000008             0.914     0.982
# 2    9    -4.932     1       0.0931      0.000051             0.444     0.986
# 3    5    -4.132     1       0.0830      0.000027             0.241     0.857
# 4    2    -4.095     1       0.0735      0.000009             0.537     0.930
#
#    valence    tempo            type                      id  \
# 0    0.176   99.624  audio_features  4GCJnyQmXZG9nBxxTuQ9E4
# 1    0.230  124.792  audio_features  0VAZaVLciiPPfS0onyzRwD
# 2    0.400  122.324  audio_features  1gzwbFfjM0VR6q9g230SBW
# 3    0.152  148.870  audio_features  0mpH8yWOUFc6HaucHdBffI
# 4    0.174  123.507  audio_features  2jdUm82MOuoA0VajeYDDGz
#
#                                     uri  \
# 0  spotify:track:4GCJnyQmXZG9nBxxTuQ9E4
# 1  spotify:track:0VAZaVLciiPPfS0onyzRwD
# 2  spotify:track:1gzwbFfjM0VR6q9g230SBW
# 3  spotify:track:0mpH8yWOUFc6HaucHdBffI
# 4  spotify:track:2jdUm82MOuoA0VajeYDDGz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4GCJnyQmXZG9...
# 1  https://api.spotify.com/v1/tracks/0VAZaVLciiPP...
# 2  https://api.spotify.com/v1/tracks/1gzwbFfjM0VR...
# 3  https://api.spotify.com/v1/tracks/0mpH8yWOUFc6...
# 4  https://api.spotify.com/v1/tracks/2jdUm82MOuoA...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4GCJ...       287722
# 1  https://api.spotify.com/v1/audio-analysis/0VAZ...       236778
# 2  https://api.spotify.com/v1/audio-analysis/1gzw...       309880
# 3  https://api.spotify.com/v1/audio-analysis/0mpH...       175536
# 4  https://api.spotify.com/v1/audio-analysis/2jdU...       304629
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
