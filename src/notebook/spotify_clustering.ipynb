# %%
import os 
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from spotify import Spotify

# My own credenctials
from utils.config import SpotifyCredectials

# %%
cred = SpotifyCredectials()

my_id = cred.my_id
my_secret = cred.my_secret

spotify = Spotify('Oasis', my_id, my_secret)

# %%
spotify.all_song_feature_df
# Out:
#                                                  name  danceability  energy  \
# 0         Columbia - Live at Knebworth, 10 August '96         0.281   0.800
# 1        Acquiesce - Live at Knebworth, 10 August '96         0.258   0.921
# 2       Supersonic - Live at Knebworth, 10 August '96         0.268   0.932
# 3            Hello - Live at Knebworth, 11 August '96         0.120   0.956
# 4   Some Might Say - Live at Knebworth, 11 August '96         0.168   0.871
# ..                                                ...           ...     ...
# 86                                      Morning Glory         0.322   0.986
# 87                                Champagne Supernova         0.301   0.863
# 88                           Don't Look Back in Anger         0.321   0.936
# 89                                       Roll With It         0.246   0.982
# 90                                  Let There Be Love         0.484   0.464
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0     2    -4.930     1       0.0449      0.000020          0.869000
# 1     0    -4.646     1       0.0647      0.000008          0.914000
# 2     9    -4.932     1       0.0931      0.000051          0.444000
# 3     5    -4.132     1       0.0830      0.000027          0.241000
# 4     2    -4.095     1       0.0735      0.000009          0.537000
# ..  ...       ...   ...          ...           ...               ...
# 86    0    -2.247     1       0.1020      0.071600          0.000576
# 87    2    -2.274     1       0.0392      0.222000          0.001840
# 88    0    -2.434     1       0.0578      0.052700          0.000000
# 89    9    -1.630     0       0.1150      0.003490          0.000148
# 90    5    -4.628     1       0.0283      0.282000          0.000000
#
#     liveness  valence    tempo            type                      id  \
# 0     0.9840    0.176   99.624  audio_features  4GCJnyQmXZG9nBxxTuQ9E4
# 1     0.9820    0.230  124.792  audio_features  0VAZaVLciiPPfS0onyzRwD
# 2     0.9860    0.400  122.324  audio_features  1gzwbFfjM0VR6q9g230SBW
# 3     0.8570    0.152  148.870  audio_features  0mpH8yWOUFc6HaucHdBffI
# 4     0.9300    0.174  123.507  audio_features  2jdUm82MOuoA0VajeYDDGz
# ..       ...      ...      ...             ...                     ...
# 86    0.6730    0.102  136.788  audio_features  2hWO7j2FnLEzu3z5BVK10K
# 87    0.3570    0.114  150.445  audio_features  4RmIr3s9oTHUvXkFtjiELI
# 88    0.0776    0.306  162.692  audio_features  3CJuUJI2Bfe3Rzfyj7GZKV
# 89    0.1900    0.225  126.608  audio_features  4hp0dKEBhuy71v1v0l8Psz
# 90    0.3430    0.137   74.032  audio_features  4nkTCEKlaWlkrT5FPrhIeX
#
#                                      uri  \
# 0   spotify:track:4GCJnyQmXZG9nBxxTuQ9E4
# 1   spotify:track:0VAZaVLciiPPfS0onyzRwD
# 2   spotify:track:1gzwbFfjM0VR6q9g230SBW
# 3   spotify:track:0mpH8yWOUFc6HaucHdBffI
# 4   spotify:track:2jdUm82MOuoA0VajeYDDGz
# ..                                   ...
# 86  spotify:track:2hWO7j2FnLEzu3z5BVK10K
# 87  spotify:track:4RmIr3s9oTHUvXkFtjiELI
# 88  spotify:track:3CJuUJI2Bfe3Rzfyj7GZKV
# 89  spotify:track:4hp0dKEBhuy71v1v0l8Psz
# 90  spotify:track:4nkTCEKlaWlkrT5FPrhIeX
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4GCJnyQmXZG9...
# 1   https://api.spotify.com/v1/tracks/0VAZaVLciiPP...
# 2   https://api.spotify.com/v1/tracks/1gzwbFfjM0VR...
# 3   https://api.spotify.com/v1/tracks/0mpH8yWOUFc6...
# 4   https://api.spotify.com/v1/tracks/2jdUm82MOuoA...
# ..                                                ...
# 86  https://api.spotify.com/v1/tracks/2hWO7j2FnLEz...
# 87  https://api.spotify.com/v1/tracks/4RmIr3s9oTHU...
# 88  https://api.spotify.com/v1/tracks/3CJuUJI2Bfe3...
# 89  https://api.spotify.com/v1/tracks/4hp0dKEBhuy7...
# 90  https://api.spotify.com/v1/tracks/4nkTCEKlaWlk...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4GCJ...       287722
# 1   https://api.spotify.com/v1/audio-analysis/0VAZ...       236778
# 2   https://api.spotify.com/v1/audio-analysis/1gzw...       309880
# 3   https://api.spotify.com/v1/audio-analysis/0mpH...       175536
# 4   https://api.spotify.com/v1/audio-analysis/2jdU...       304629
# ..                                                ...          ...
# 86  https://api.spotify.com/v1/audio-analysis/2hWO...       301933
# 87  https://api.spotify.com/v1/audio-analysis/4RmI...       449333
# 88  https://api.spotify.com/v1/audio-analysis/3CJu...       306440
# 89  https://api.spotify.com/v1/audio-analysis/4hp0...       240533
# 90  https://api.spotify.com/v1/audio-analysis/4nkT...       330080
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 86               4
# 87               4
# 88               4
# 89               4
# 90               4
#
# [391 rows x 19 columns]
